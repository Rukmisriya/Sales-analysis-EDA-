# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# reading csv file
df = pd.read_csv(r"D:\CED Learn/Supermarket Data-Analysis/supermarket_sales - Sheet1.csv")
# df = pd.read_excel(r"D:\CED Learn/Supermarket Data-Analysis/supermarket_sales - Sheet1.xlsx")
# df = pd.read_json(r"D:\CED Learn/Supermarket Data-Analysis/supermarket_sales - Sheet1.json")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# converting to excel
file_name = "Supermarket Data-Analysis.xlsx"
df.to_excel(file_name)
# df.to_json(file_name)
# df.to_html(file_name)

# %%
#first 10 records
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# printing all columns
print(df.columns)
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
#data types of columns
print(df.dtypes)
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
# no of rows and columns
print(df.shape)
# Out:
# (1000, 17)

# %%
# info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# ------NO Need of data type conversion and no null values in dataset------------

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
print(df.dtypes)
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
#Adding'Month' column
df['date']= df['Date'].dt.day
df['Day']=df['Date'].dt.strftime('%A')
df['Month'] = df['Date'].dt.strftime('%B')
df['Year']= df['Date'].dt.year
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#Descriptive Statistics
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        cogs  gross margin percentage  \
# count                        1000  1000.00000             1.000000e+03
# mean   2019-02-14 00:05:45.600000   307.58738             4.761905e+00
# min           2019-01-01 00:00:00    10.17000             4.761905e+00
# 25%           2019-01-24 00:00:00   118.49750             4.761905e+00
# 50%           2019-02-13 00:00:00   241.76000             4.761905e+00
# ...

# %%
# which payment mode is used the most Prefered
df['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
# which gender takes most memberships
import warnings
warnings.simplefilter(action="ignore" , category = FutureWarning)

most_members = df.groupby('Customer type')['Gender'].value_counts()
most_members.plot(kind='bar', color='skyblue')
# plotting no of wins vs teams
plt.title('Gender wise membership analysis')
plt.xlabel('(Gender,Customer type)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# No of customers from respective cities
df['City'].value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
# Count of customer types
df['Customer type'].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %%
# Which gender customers are more
df['Gender'].value_counts()
# Out:
# Gender
# Female    501
# Male      499
# Name: count, dtype: int64

# %%
# count of variety of products are selling 
df['Product line'].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %% [markdown]
# -------SALES ANALYSIS--------

# %%
# Productline wise sales
product_sales = df.groupby('Product line')['Total'].sum().sort_values(ascending=False)
print(product_sales)
# Out:
# Product line
# Food and beverages        56144.8440
# Sports and travel         55122.8265
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Home and lifestyle        53861.9130
# Health and beauty         49193.7390
# Name: Total, dtype: float64

# %%
# Identify best-selling product lines
print("Best-Selling Product Lines:")
print(product_sales.head())

# Identify least-selling product lines
print("\nLeast-selling Product Lines:")
print(product_sales.tail())
# Out:
# Best-Selling Product Lines:
# Product line
# Food and beverages        56144.8440
# Sports and travel         55122.8265
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Home and lifestyle        53861.9130
# Name: Total, dtype: float64
#
# Least-selling Product Lines:
# Product line
# Sports and travel         55122.8265
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Home and lifestyle        53861.9130
# Health and beauty         49193.7390
# Name: Total, dtype: float64

# %%
#Product line sales analysis
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='Product line', y='Total', palette='Set2')
plt.title('Sales by Product Line')
plt.show()

# %%
#Dividing the customers
# sales analysis by Customer type
customer_type_sales = df.groupby('Customer type')['Total'].sum()
print("Sales by Customer Type:")
print(customer_type_sales)

# sales analysis by Gender
gender_sales = df.groupby('Gender')['Total'].sum()
print("\nSales by Gender:")
print(gender_sales)
# Out:
# Sales by Customer Type:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64
#
# Sales by Gender:
# Gender
# Female    167882.925
# Male      155083.824
# Name: Total, dtype: float64

# %%
# Monthly sales analysis
month_sales = df.groupby('Month')['Total'].sum()
plt.figure(figsize=(12, 6))
month_sales.plot(kind='line', color=['orange'])
plt.title('Monthly sales Analysis')
plt.xlabel('Months')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
# City sales Analysis relative to each and other
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='City', y='Total', palette='Set3')
plt.title('Sales Distribution by City')
plt.show()

# %%
# Every day sales analysis
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Day', y='Total', palette='Set3')
plt.title('Sales Distribution by City')
plt.show()
# Out:
# C:\Users\SATHI\AppData\Local\Temp\ipykernel_18612\3672189673.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df, x='Day', y='Total', palette='Set3')

# %% [markdown]
# ------Corelation------

# %%
df.corr(numeric_only = True)
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# date                       0.057021 -0.043347 -0.002515 -0.002515 -0.002515
# Year                            NaN       NaN       NaN       NaN       NaN
#
#                          gross margin percentage  gross income    Rating  \
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only = True),cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# relation between product line and gender
df.groupby(['Product line', 'Gender']).size().unstack()
# Out:
# Gender                  Female  Male
# Product line
# Electronic accessories      84    86
# Fashion accessories         96    82
# Food and beverages          90    84
# Health and beauty           64    88
# Home and lifestyle          79    81
# Sports and travel           88    78

# %%
plt.figure(figsize=(15, 10))
df1=df.groupby(['Product line', 'Gender']).size().unstack()
df1.plot(kind='bar')
plt.title('Product Line - Gender Analysis')
plt.legend()
plt.show()

# %%
# Product line performance by branch
df.groupby(['Product line', 'Branch'])['Total'].sum().unstack()
# Out:
# Branch                           A           B           C
# Product line
# Electronic accessories  18317.1135  17051.4435  18968.9745
# Fashion accessories     16332.5085  16413.3165  21560.0700
# Food and beverages      17163.1005  15214.8885  23766.8550
# Health and beauty       12597.7530  19980.6600  16615.3260
# Home and lifestyle      22417.1955  17549.1645  13895.5530
# Sports and travel       19372.6995  19988.1990  15761.9280

# %%
# best-performing branch for each product line
plt.figure(figsize=(15, 10))
df1=df.groupby(['Product line', 'Branch'])['Total'].sum().unstack()
df1.plot(kind='bar')
plt.title('Product Line - Branch Analysis')
plt.legend()
plt.show()

# %%
# Finding products with lower ratings
low_rated = df[df['Rating'] < 6] 
print("\nProducts with Ratings Below 6:")
print(low_rated[['Product line', 'Total', 'Rating']].head())
# Out:
# Products with Ratings Below 6:
#               Product line     Total  Rating
# 4        Sports and travel  634.3785     5.3
# 5   Electronic accessories  627.6165     4.1
# 6   Electronic accessories  433.6920     5.8
# 9       Food and beverages  172.7460     5.9
# 10     Fashion accessories   60.8160     4.5

# %%
# gross income
df['gross income'].describe()
# Out:
# count    1000.000000
# mean       15.379369
# std        11.708825
# min         0.508500
# 25%         5.924875
# 50%        12.088000
# 75%        22.445250
# max        49.650000
# Name: gross income, dtype: float64

# %%
# daily sales profit
daily_profit=df.groupby(df['Date'])['gross income'].sum().reset_index()

# %%
plt.figure(figsize=(10,6))
plt.plot(daily_profit[['Date']], daily_profit['gross income'], marker='o', linestyle='-', color='skyblue')
plt.title('Daily Sales Profit Analysis')
plt.xlabel('Date')
plt.ylabel('Gross Income (Profit)')
plt.show()
